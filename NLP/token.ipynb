# %% [markdown]
# <a href="https://colab.research.google.com/github/kankekarsaurabh/Machine-learning/blob/practice/NLP/token.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
corpus="""Hello welcome, to NLP processing practice.
Please complete all the learning materials and practice properly.
I also love playing video game's.
"""

# %%
print(corpus)
# Out:
# Hello welcome, to NLP processing practice.
# Please complete all the learning materials and practice properly.
# I also love playing video game's.

# %%
##tokenization
##sentence to paragraphs
import nltk
from nltk.tokenize import sent_tokenize

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
  print(sentence)
# Out:
# Hello welcome, to NLP processing practice.
# Please complete all the learning materials and practice properly.
# I also love playing video game's.

# %%
#tokenize
#paragrah words
#sentence--words

from nltk.tokenize import word_tokenize

word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'NLP',
#  'processing',
#  'practice',
#  '.',
#  'Please',
#  'complete',
#  'all',
#  'the',
#  'learning',
#  'materials',
#  'and',
#  'practice',
#  'properly',
#  '.',
#  'I',
#  'also',
#  'love',
#  'playing',
#  'video',
#  'game',
#  "'s",
#  '.']

# %%
for sentence in documents:
  print(word_tokenize(sentence))
# Out:
# ['Hello', 'welcome', ',', 'to', 'NLP', 'processing', 'practice', '.']
# ['Please', 'complete', 'all', 'the', 'learning', 'materials', 'and', 'practice', 'properly', '.']
# ['I', 'also', 'love', 'playing', 'video', 'game', "'s", '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'NLP',
#  'processing',
#  'practice',
#  '.',
#  'Please',
#  'complete',
#  'all',
#  'the',
#  'learning',
#  'materials',
#  'and',
#  'practice',
#  'properly',
#  '.',
#  'I',
#  'also',
#  'love',
#  'playing',
#  'video',
#  'game',
#  "'",
#  's',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'NLP',
#  'processing',
#  'practice.',
#  'Please',
#  'complete',
#  'all',
#  'the',
#  'learning',
#  'materials',
#  'and',
#  'practice',
#  'properly.',
#  'I',
#  'also',
#  'love',
#  'playing',
#  'video',
#  'game',
#  "'s",
#  '.']
