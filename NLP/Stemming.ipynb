# %% [markdown]
# <a href="https://colab.research.google.com/github/kankekarsaurabh/Machine-learning/blob/practice/NLP/Stemming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Stemming
#
# Process of reducing word to it word stem

# %%
#words
import nltk

# %%
words=['writes','writing', 'eat', 'eating', 'final', 'finale', 'hist', 'historical']

# %% [markdown]
# Porter Stemmer

# %%
#porter stemmer

from nltk.stem import PorterStemmer

# %%
stemming= PorterStemmer()

# %%
for word in words:
  print(word+"---->"+stemming.stem(word))
# Out:
# writes---->write
# writing---->write
# eat---->eat
# eating---->eat
# final---->final
# finale---->final
# hist---->hist
# historical---->histor

# %% [markdown]
# **Regex Stemmer**
#
#
# A Regex Stemmer is a type of stemming algorithm that utilizes regular expressions to identify and remove morphological affixes (like suffixes or prefixes) from words, thereby approximating their root forms. This method is often used in Natural Language Processing (NLP) to reduce words to a common base for text analysis and information retrieval.

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer=RegexpStemmer('ing|s$|e$|able$', min=4)

# %%
reg_stemmer.stem("ingeating")
# Out:
# 'eat'

# %% [markdown]
# Snow ball Stemmer

# %%
from nltk.stem import SnowballStemmer

# %%
snowball=SnowballStemmer('english')

# %%
for word in words:
  print(word+"....>"+snowball.stem(word))
# Out:
# writes....>write
# writing....>write
# eat....>eat
# eating....>eat
# final....>final
# finale....>final
# hist....>hist
# historical....>histor

# %% [markdown]
# Comparison between normal stemming and snowball stemmer

# %%
stemming.stem("fairly"), stemming.stem("sportingly")
# Out:
# ('fairli', 'sportingli')

# %%
snowball.stem("fairly"), snowball.stem('sportingly')
# Out:
# ('fair', 'sport')
