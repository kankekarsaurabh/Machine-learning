# %% [markdown]
# <a href="https://colab.research.google.com/github/kankekarsaurabh/Machine-learning/blob/practice/NLP/Stemming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Stemming
#
# Process of reducing word to it word stem

# %%
# Out:
#   File "/tmp/ipython-input-3255979000.py", line 3
#     Process of reducing word to it word stem
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# Stemming
#
# Process of reducing word to it word stem
